# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# #Dr_Shoayee_Assignment

# %% [markdown]
# #My Name is Dr.Shoayee, I am writing this document in fulfilling the requirements of coursera courses

# %% [markdown]
# #Exercise 4 - Create a markdown cell to list data science languages:data science languages : Python, R , Scala

# %% [markdown]
# #data science librarires: Some of the commonly used libraries used by Data Scientists include:
#
# TensorFlow. NumPy. SciPy. Pandas. Matplotlib. Keras. SciKit-Learn. PyTorch. Scrapy. BeautifulSoup. LightGBM. ELI5. Theano. NuPIC. Ramp. Pipenv. Bob. PyBrain. Caffe2. Chainer.

# %% [markdown]
# data scinece tools: SAS. It is one of those data science tools which are specifically designed for statistical operation Apache Spark BigML

# %% [markdown]
# #Excercies 7: Create a markdown cell introducing arithmetic expression examples: 1- addition: a+b , multiplication a*b, round down a//b

# %%
3*4+5
# Out:
# Running cells with 'c:\Users\user\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/user/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
minutes = 320
hours= minutes/60
print (hours)

# %% [markdown]
# #objective: This course introduced you to multiple data science tools, and in this final project, you will use Jupyterlite Notebook, one of the easiest tools to share publicly.

# %% [markdown]
# Author name: Dr.Shoayee
